# %% [markdown]
# <a href="https://colab.research.google.com/github/YukiAoki-GU/-Mathematical_analysis_by_Python/blob/main/AI%E3%82%92%E4%BD%BF%E3%81%A3%E3%81%9F%E3%83%AA%E3%82%A2%E3%83%AB%E3%83%AF%E3%83%BC%E3%83%AB%E3%83%89%E3%83%87%E3%83%BC%E3%82%BF%E3%81%AE%E8%A9%95%E4%BE%A12025_noGD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIを使ったリアルワールドデータ(RWD)の評価

# %% [markdown]
# ## **RWDとは？**

# %%
#こちらの動画を見てください。
from IPython.display import HTML

HTML("""
<a href="https://www.youtube.com/watch?v=UtH22-nplVU" target="_blank">
▶ YouTubeで動画を見る
</a>
""")
# Out:
# <a href="https://www.youtube.com/watch?v=UtH22-nplVU" target="_blank">
# ▶ YouTubeで動画を見る
# </a>

# %% [markdown]
# RWD には明確な定義はありませんが、大規模な患者レジストリーや保険データベース、電子カルテデータを含むデータベースなど、日々の臨床から収集した患者情報のデータベースの総称の意味合いで広く使われています。
#
#
#
# 公的機関が運営する代表的なリアルワールドデータは以下：
# * NDB(ナショナルデータベース)：厚生労働省が提供する、公益目的のリアルワールドデータ。データの提供は行政機関や大学、研究をする独立行政法人、国直轄の公益法人や国の行政機関に限られる。
# * MID-NET(医療情報データベース、ミッドネット): 全国23の大病院から電子カルテなどを集めた、製造販売後の調査、もしくは公益性の高い研究のために用いられるリアルワールドデータ。PMDAが管理・運営している。提供は、厚生労働省が開発要請をした医薬品についての実態調査、国や自治体、独立行政法人などの公的研究費による研究に限られる。

# %% [markdown]
# ## なぜRWDなのか？
# 日常診療の中で集められたデータであり、例えば
# - 電子カルテ(EHR)
# - DPCデータ
# - レセプト
# - 患者登録・レジストリ
# - ウエアブル
# - バイオマーカー
# - 検査データ
#
# 臨床研究のスタンダードはランダム化比較試験(Randomized Controlled Trial: RCT)ですが、臨床研究のゴールド・スタンダードはランダム化比較試験 （Randomized Controlled Trial: 以下 RCT）ですが、特に医療の世界では RCT が倫理的または費用的な面で実施困難であることが多く、また厳しく統制された RCT で得られた知見を実際の臨床に応用できるか保証されないという問題があるため（外的妥当性が保証されない）、近年 RWD を用いた分析の可能性に注目が集まっています。
#
# 1. 臨床試験の限界
# 従来の臨床試験（ランダム化比較試験、RCT）は、厳密な環境下で行われるため、患者の選定基準が非常に厳格です。これにより、現実の医療現場での患者層（高齢者、併存疾患を持つ患者など）を十分に反映できない場合があります。RWDは、日常の診療で得られる実際のデータを基にしているため、より多様な患者層に基づく実際の医療効果や安全性を評価できます。
#
# 2. 医薬品の効果・安全性の長期的評価
# 新薬が市場に出た後、臨床試験では確認できなかった長期的な安全性や副作用が現れることがあります。RWDは、医薬品が市場に出た後のリアルタイムでのデータを集め、長期間にわたる効果や副作用の監視に役立ちます。
#
# 3. 患者中心の医療へのシフト
# 医療は、個別化医療（Precision Medicine）や患者中心の医療に向かっています。RWDは、患者の日常生活や実際の医療現場での経験を反映するデータであり、個々の患者のニーズや治療効果をよりよく理解するための情報源となります。
#
# 4. コスト削減と効率化
# 従来の臨床試験は非常にコストが高く、時間もかかります。一方、電子カルテ（EHR）、保険データ、ウェアラブルデバイスなどから得られるRWDは、比較的低コストで迅速にデータを収集できるため、医薬品開発や政策決定において重要な役割を果たします。
#
# 5. 政策と規制の変化
# RWDが大切になった背景として、医療品に関する法律の改正があります。2018年4月に施行された「医薬品の製造販売後の調査及び試験の実施の基準に関する省令（GPSP省令）」の[改正](https://www.pmda.go.jp/files/000220766.pdf)により、製造販売後の安全性監視活動にリアルワールドデータ（RWD）を活用することが認められました。薬事承認においても、条件付き早期承認制度下での調査でRWDの活用が認められ、さらにはPMDA(独立行政法人医療品医療機器総合機構)のレジストリ・データベースに関する相談窓口の整備されてきました。
#
# 6. デジタルヘルス技術の進化
# ウェアラブルデバイス、スマートフォン、IoTなどのデジタル技術が普及し、個々の患者の日常生活での健康状態や行動をリアルタイムでモニタリングできるようになりました。これにより、RWDの質と量が飛躍的に向上し、より精密な分析が可能になっています。
#
# このように、リアルワールドデータは従来の臨床試験の補完として、あるいはそれに代わる方法として、医療・ヘルスケアの意思決定においてますます重要な役割を担っています。

# %% [markdown]
# ---
# ## **AIを使ったRWDの評価**

# %%
#こちらの動画を見てください。
from IPython.display import HTML

HTML("""
<a href="https://www.youtube.com/watch?v=gugq9ydf8b8" target="_blank">
▶ YouTubeで動画を見る
</a>
""")
# Out:
# <a href="https://www.youtube.com/watch?v=gugq9ydf8b8" target="_blank">
# ▶ YouTubeで動画を見る
# </a>

# %% [markdown]
# 機械学習による予測モデルを実際の医療現場で診断補助として運用するのであれば、「AIの予測はどの程度正しいのか？」を説明できることが重要。\
# 「機械学習」はコンピュータに物事を学習させることを総称した言葉であり、機械学習の具体的な手法(アルゴリズム)は以下のように多岐にわたります。
#
# *   二値分類：\
# データを2つのクラスに分類 → 陰性 or 陽性
# *   回帰による二値分類：\
# データの分布をグラフで表したとき、直線を使ってデータを二分(線型回帰)
# *   多項式回帰による二値分類：\
# 多項式を使った曲線を使ってデータを二分
# *   ロジスティック回帰による二値分類：\
# 回帰の手法では分類困難な場合。例えば、メールのスパムメールと通常メールの二分。このような場合は、「スパムである可能性は80%」のように、確率によるロジスティック回帰で分類
# *   ニューラルネットワーク：\
# 動物の神経細胞を模した「人工ニューロン」を複数繋ぎ合わせることで分類する方法。ニューロンの連結数を増やし、人間の脳に近い学習を行わせる手法のことを「**深層学習(ディープラーニング)**」と呼ぶ。

# %% [markdown]
# ---
# ## **混同行列、ROC曲線、AUC**

# %%
#こちらの動画を見てください。
from IPython.display import HTML

HTML("""
<a href="https://www.youtube.com/watch?v=opBZQOa8EZA" target="_blank">
▶ YouTubeで動画を見る
</a>
""")
# Out:
# <a href="https://www.youtube.com/watch?v=opBZQOa8EZA" target="_blank">
# ▶ YouTubeで動画を見る
# </a>

# %% [markdown]
# 予想の正しさを定量的に評価するにはどうすれば良いか？\
# データを2つのクラス(陰性と陽性)に二値分類するが、
# * 陰性と分類し本当に陰性であったもの (True Negative)
# * 陽性と分類し本当に陽性であったもの (True Positive)
#
# は、正しい分類である。一方、
# * 陰性と分類し本当は陽性であったもの (False Positive)
# * 陽性と分類し本当は陰性であったもの (False Negative)
#
# は、誤った分類である。これら4成分を行列としたものを**混同行列**(Confusion Matrix)と言う。
#
# $$
#         \left[\begin{array}{c|cc}
#             TP & FP\\
#             \hline
#             FN & TN\\
#         \end{array}\right] \quad
# $$
#
# 横軸をFPR(False Positive Rate)、縦軸をTPR(True Positive Rate)としたグラフを**ROC曲線**(Receiver Operating Characteristic曲線)という。\
# ROC曲線の下側の面積比が**AUC**(Area Under the ROC Curve)である。\
# AUCは0から1の値を取り、1に近いほど分類が正しいことを示す。

# %% [markdown]
# ---
# ## **ViTとCNNで画像の二値分類**
# レントゲン画像を男女に分類しよう。

# %%
#こちらの動画を見てください。
from IPython.display import HTML

HTML("""
<a href="https://www.youtube.com/watch?v=3JxREAM9YL0" target="_blank">
▶ YouTubeで動画を見る
</a>
""")
# Out:
# <a href="https://www.youtube.com/watch?v=3JxREAM9YL0" target="_blank">
# ▶ YouTubeで動画を見る
# </a>

# %%
# !pip install timm #モデルのインストール
# 必要なライブラリをインポート
from __future__ import print_function

import glob
import os
import random
import cv2
import time

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from PIL import Image
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, transforms
from torchvision.transforms import v2
from tqdm.notebook import tqdm

from pathlib import Path
import seaborn as sns
import timm
from pprint import pprint
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, roc_curve, auc
import matplotlib.pyplot as plt

# %% [markdown]
# GULMSの「画像データ」から[x-ray.zip](https://mdl.media.gunma-u.ac.jp/course/section.php?id=33666)をダウンロードし、`/content`に置いてください。

# %%
# %cd /content
# !unzip /content/x-ray.zip -d /content/x-ray
# Out:
# /content
# Archive:  /content/x-ray.zip
#    creating: /content/x-ray/x-ray/
#   inflating: /content/x-ray/__MACOSX/._x-ray
#    creating: /content/x-ray/x-ray/test/
#   inflating: /content/x-ray/__MACOSX/x-ray/._test
#    creating: /content/x-ray/x-ray/train/
#   inflating: /content/x-ray/__MACOSX/x-ray/._train
#    creating: /content/x-ray/x-ray/validation/
#   inflating: /content/x-ray/__MACOSX/x-ray/._validation
#    creating: /content/x-ray/x-ray/test/male/
#   inflating: /content/x-ray/__MACOSX/x-ray/test/._male
#    creating: /content/x-ray/x-ray/test/female/
#   inflating: /content/x-ray/__MACOSX/x-ray/test/._female
#    creating: /content/x-ray/x-ray/train/male/
#   inflating: /content/x-ray/__MACOSX/x-ray/train/._male
#    creating: /content/x-ray/x-ray/train/female/
#   inflating: /content/x-ray/__MACOSX/x-ray/train/._female
#    creating: /content/x-ray/x-ray/validation/male/
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/._male
#    creating: /content/x-ray/x-ray/validation/female/
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/._female
#   inflating: /content/x-ray/x-ray/test/male/JPCNN079.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN079.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN045.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN045.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN086.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN086.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN093.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN093.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN044.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN044.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN050.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN050.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN046.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN046.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN091.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN091.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN053.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN053.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN057.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN057.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN056.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN056.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN054.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN054.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN068.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN068.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN082.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN082.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN055.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN055.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN065.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN065.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN072.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN072.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN076.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN076.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN089.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN089.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN088.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN088.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN063.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN063.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN075.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN075.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN061.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN061.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN049.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN049.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN048.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN048.png
#   inflating: /content/x-ray/x-ray/test/male/JPCNN060.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/male/._JPCNN060.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN092.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN092.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN087.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN087.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN078.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN078.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN085.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN085.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN090.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN090.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN084.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN084.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN080.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN080.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN081.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN081.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN083.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN083.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN069.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN069.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN058.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN058.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN070.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN070.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN064.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN064.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN071.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN071.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN059.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN059.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN067.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN067.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN073.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN073.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN066.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN066.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN062.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN062.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN077.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN077.png
#   inflating: /content/x-ray/x-ray/test/female/JPCNN074.png
#   inflating: /content/x-ray/__MACOSX/x-ray/test/female/._JPCNN074.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN094.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN094.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN123.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN123.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN083.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN083.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN097.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN097.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN068.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN068.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN040.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN040.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN120.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN120.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN121.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN121.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN135.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN135.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN041.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN041.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN086.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN086.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN092.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN092.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN045.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN045.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN118.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN118.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN130.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN130.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN078.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN078.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN044.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN044.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN093.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN093.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN087.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN087.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN091.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN091.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN046.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN046.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN126.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN126.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN047.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN047.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN053.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN053.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN090.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN090.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN141.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN141.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN035.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN035.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN143.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN143.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN142.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN142.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN036.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN036.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN026.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN026.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN032.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN032.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN152.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN152.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN146.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN146.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN153.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN153.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN018.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN018.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN001.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN001.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN014.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN014.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN028.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN028.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN016.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN016.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN007.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN007.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN013.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN013.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN012.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN012.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN011.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN011.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN089.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN089.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN076.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN076.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN103.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN103.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN063.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN063.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN049.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN049.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN061.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN061.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN129.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN129.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN115.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN115.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN101.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN101.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN074.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN074.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN064.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN064.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN070.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN070.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN058.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN058.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN110.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN110.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN104.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN104.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN139.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN139.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN111.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN111.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN065.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN065.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN098.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN098.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN073.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN073.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN107.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN107.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN112.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN112.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN106.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN106.png
#   inflating: /content/x-ray/x-ray/train/male/JPCLN066.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/male/._JPCLN066.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN080.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN080.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN057.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN057.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN043.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN043.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN137.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN137.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN136.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN136.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN122.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN122.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN042.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN042.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN056.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN056.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN081.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN081.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN095.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN095.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN054.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN054.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN108.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN108.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN134.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN134.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN109.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN109.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN055.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN055.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN069.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN069.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN096.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN096.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN082.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN082.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN051.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN051.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN079.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN079.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN131.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN131.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN125.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN125.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN119.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN119.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN124.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN124.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN050.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN050.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN085.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN085.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN052.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN052.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN132.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN132.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN133.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN133.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN127.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN127.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN084.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN084.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN008.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN008.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN034.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN034.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN020.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN020.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN140.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN140.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN154.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN154.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN021.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN021.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN009.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN009.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN023.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN023.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN037.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN037.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN022.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN022.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN147.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN147.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN033.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN033.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN027.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN027.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN031.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN031.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN025.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN025.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN019.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN019.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN145.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN145.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN151.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN151.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN150.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN150.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN144.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN144.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN024.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN024.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN030.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN030.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN029.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN029.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN015.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN015.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN149.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN149.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN148.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN148.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN002.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN002.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN017.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN017.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN003.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN003.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN006.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN006.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN010.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN010.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN004.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN004.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN038.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN038.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN039.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN039.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN005.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN005.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN062.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN062.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN102.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN102.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN116.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN116.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN117.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN117.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN077.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN077.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN088.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN088.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN075.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN075.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN100.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN100.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN114.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN114.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN128.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN128.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN060.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN060.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN048.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN048.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN138.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN138.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN105.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN105.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN059.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN059.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN071.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN071.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN067.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN067.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN113.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN113.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN072.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN072.png
#   inflating: /content/x-ray/x-ray/train/female/JPCLN099.png
#   inflating: /content/x-ray/__MACOSX/x-ray/train/female/._JPCLN099.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN032.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN032.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN026.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN026.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN033.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN033.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN025.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN025.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN031.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN031.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN020.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN020.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN034.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN034.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN008.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN008.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN035.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN035.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN037.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN037.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN023.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN023.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN022.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN022.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN036.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN036.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN041.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN041.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN007.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN007.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN006.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN006.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN012.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN012.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN004.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN004.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN010.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN010.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN011.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN011.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN005.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN005.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN039.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN039.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN014.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN014.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN016.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN016.png
#   inflating: /content/x-ray/x-ray/validation/male/JPCNN002.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/male/._JPCNN002.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN027.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN027.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN019.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN019.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN030.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN030.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN024.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN024.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN018.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN018.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN009.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN009.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN021.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN021.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN051.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN051.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN052.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN052.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN047.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN047.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN043.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN043.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN042.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN042.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN040.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN040.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN013.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN013.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN038.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN038.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN001.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN001.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN015.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN015.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN029.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN029.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN028.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN028.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN003.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN003.png
#   inflating: /content/x-ray/x-ray/validation/female/JPCNN017.png
#   inflating: /content/x-ray/__MACOSX/x-ray/validation/female/._JPCNN017.png

# %% [markdown]
# `/content/x-ray`のディレクトリができていることを確認してください。

# %%
# データの読み込みを確認
files = glob.glob('/content/x-ray/*/*/*.png')
random_idx = np.random.randint(1, len(files), size=9)
fig, axes = plt.subplots(3, 3, figsize=(8, 6))

for idx, ax in enumerate(axes.ravel()):
    img = Image.open(files[idx])
    ax.imshow(img)

# %%
device = 'cuda'
train_dataset_dir = Path('/content/x-ray/train') #訓練データ
val_dataset_dir = Path('/content/x-ray/validation') #検証データ(訓練データでは良い精度で予想できるが、それ以外のデータでは、予測が当てにならない→過学習)
test_dataset_dir = Path('/content/x-ray/test') #テストデータ

# %%
# transformを使って、データセットの画像の前処理を行います。
#画像のサイズを224×224にリサイズ
#左右反転によるData Augmentation
#Tensor型へデータ変更
#正規化

train_transforms = transforms.Compose(
    [
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]
)

val_transforms = transforms.Compose(
    [
        transforms.Resize(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]
)

test_transforms = transforms.Compose(
    [
        transforms.Resize(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]
)

# データセット（画像とラベルのセット）を作成
train_data = datasets.ImageFolder(train_dataset_dir,train_transforms)
valid_data = datasets.ImageFolder(val_dataset_dir, val_transforms)
test_data = datasets.ImageFolder(test_dataset_dir, test_transforms)

# データをバッチに分ける。今回は、batch_sizeを16
train_loader = DataLoader(dataset = train_data, batch_size=16, shuffle=True )
valid_loader = DataLoader(dataset = valid_data, batch_size=16, shuffle=False)
test_loader = DataLoader(dataset = test_data, batch_size=16, shuffle=False)

# %% [markdown]
# 「編集→ノートブックの設定→ハードウェアアクセラレータ→GPU」でGPUの処理に変更してください。

# %% [markdown]
# ---
# ## ViTで画像分類

# %%
# modelのリストを表示
model_names = timm.list_models(pretrained=True)
pprint(model_names)

# %%
#今回は‘vit_base_patch16_224_in21k’を使用
model = timm.create_model('vit_base_patch16_224_in21k', pretrained=True, num_classes=2)
#model = timm.create_model('tf_efficientnetv2_s_in21ft1k', pretrained=True, num_classes=2)
model = model.to(device)

# %%
# 学習条件
epochs = 100
lr = 0.001

#損失関数、活性化関数の設定
# loss function
criterion = nn.CrossEntropyLoss()
# optimizer
optimizer = optim.Adam(model.parameters(), lr=lr)

# 学習ループの設定、実行
best_loss = None

# Accuracy計算用の関数
def calculate_accuracy(output, target):
    output = (torch.sigmoid(output) >= 0.5)
    target = (target == 1.0)
    accuracy = torch.true_divide((target == output).sum(dim=0), output.size(0)).item()
    return accuracy

train_acc_list = []
val_acc_list = []
train_loss_list = []
val_loss_list = []

for epoch in range(epochs):
    epoch_loss = 0
    epoch_accuracy = 0

    for data, label in tqdm(train_loader):
        data = data.to(device)
        label = label.to(device)

        output = model(data)
        loss = criterion(output, label)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        acc = (output.argmax(dim=1) == label).float().mean()
        epoch_accuracy += acc / len(train_loader)
        epoch_loss += loss / len(train_loader)

    with torch.no_grad():
        epoch_val_accuracy = 0
        epoch_val_loss = 0
        for data, label in valid_loader:
            data = data.to(device)
            label = label.to(device)

            val_output = model(data)
            val_loss = criterion(val_output, label)

            acc = (val_output.argmax(dim=1) == label).float().mean()
            epoch_val_accuracy += acc / len(valid_loader)
            epoch_val_loss += val_loss / len(valid_loader)

    print(
        f"Epoch : {epoch+1} - loss : {epoch_loss:.4f} - acc: {epoch_accuracy:.4f} - val_loss : {epoch_val_loss:.4f} - val_acc: {epoch_val_accuracy:.4f}\n"
    )

    train_acc_list.append(epoch_accuracy)
    val_acc_list.append(epoch_val_accuracy)
    train_loss_list.append(epoch_loss)
    val_loss_list.append(epoch_val_loss)

    if (best_loss is None) or (best_loss > val_loss):
        best_loss = val_loss
        model_path = '/content/bestViTmodel.pth' #重みファイル名
        #model_path = '/content/bestmodel_efficientnet.pth'
        torch.save(model.state_dict(), model_path)

    print()

# %%
# テストデータによる検証
def evaluate_model(model, test_loader):
    model.load_state_dict(torch.load("/content/bestViTmodel.pth")) #重みファイル名
    model.eval()
    predictions = []
    actuals = []
    probas = []
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            probas.extend(outputs[:, 1].cpu().numpy())  # 二番目のクラス（陽性クラス）の確率
            predictions.extend(predicted.cpu().numpy())
            actuals.extend(labels.cpu().numpy())


    # 指標の計算
    confusion = confusion_matrix(actuals, predictions)
    accuracy = accuracy_score(actuals, predictions)
    recall = recall_score(actuals, predictions)  # 感度
    specificity = recall_score(actuals, predictions, pos_label=0)
    precision = precision_score(actuals, predictions)  # PPV
    npv = precision_score(actuals, predictions, pos_label=0)  # NPV
    f1 = f1_score(actuals, predictions)
    auc = roc_auc_score(actuals, probas)


    #print("混同行列:\n", confusion)
    print(f"Accuracy: {accuracy:.4f}")
    print(f"感度: {recall:.4f}")
    print(f"特異度: {specificity:.4f}")
    print(f"PPV: {precision:.4f}")
    print(f"NPV: {npv:.4f}")
    print(f"F-Score: {f1:.4f}")
    print(f"AUC: {auc:.4f}")


    # Confusion matrixの描画
    # 混同行列の可視化
    plt.figure(figsize=(7, 6))
    sns.heatmap(confusion, annot=True, fmt="d", cmap="Blues")
    plt.title("Confusion Matrix")
    plt.ylabel("True")
    plt.xlabel("Predicted")
    plt.show()


    # ROC曲線の描画
    fpr, tpr, thresholds = roc_curve(actuals, probas)
    plt.figure(figsize=(6,6))
    plt.plot(fpr, tpr, color='blue', label='ROC curve (AUC = %0.2f)' % auc)
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc="lower right")
    plt.show()


evaluate_model(model, test_loader)

# %% [markdown]
# ---
# ## CNNで画像分類
# * モデル名を`vit_base_patch16_224_in21k` → `tf_efficientnetv2_s_in21ft1k`
# * 重みファイル名を`/content/drive/MyDrive/bestViTmodel.pth` → `/content/drive/MyDrive/bestmodel_efficientnet.pth`
#
# に変更して、CNNにおける混同行列、ROC曲線、AUCを計算しなさい。
